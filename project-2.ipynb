# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# Evgeny Yanochkin

# %% [markdown]
# I am interested in data science because I love data and machine learning

# %% [markdown]
# ### Get a sum 1+1

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# Numbered list:
#
# 1.Item_1\
# 2.Item_2
#
# Bulleted list of cars:
#
# * BMW
# * AUDI
# * MB
# * LADA
